# %%
import pandas as pd
import os
import shutil

# %%
# Read in data
data = pd.read_csv('vgg19_results.csv')
#data_retrained = pd.read_csv('vgg19_results_retrained.csv')

# %%
def analysis(data):
    correct = data[data["correct"] == "y"]
    # Find out highest and lowest confidence score for each category
    # Group by 'true label' and find the min and max of 'true confidence score'
    confidence_summary = correct.groupby("true label")["true confidence score"].agg(["min", "max"]).reset_index()
    # Find the corresponding images for min and max confidence scores
    min_conf_images = correct.loc[correct.groupby("true label")["true confidence score"].idxmin(), ["true label", "image", "true confidence score"]]
    max_conf_images = correct.loc[correct.groupby("true label")["true confidence score"].idxmax(), ["true label", "image", "true confidence score"]]
    
    # Merge the results into a single dataframe
    confidence_images = min_conf_images.merge(max_conf_images, on="true label", suffixes=("_min", "_max"))

    return confidence_images

# %%
# Thresholds
high_threshold = 0.99
low_threshold = 0.2

df_correct = data[data["correct"] == "y"]

# Filter rows
high_conf_images = df_correct[df_correct["true confidence score"] > high_threshold]
low_conf_images = df_correct[df_correct["true confidence score"] < low_threshold]

# %%
# Function to convert a float to 4 significant digits as a string
def format_confidence(conf):
    return f"{conf:.4g}"

# Function to copy and rename images
def copy_and_rename_images(dataframe, folder_name):
    for _, row in dataframe.iterrows():
        true_label = row['true label']
        image_path = row['image']
        confidence = row['true confidence score']
        ext = os.path.splitext(image_path)[-1]  # preserve file extension (e.g., .jpg, .png)

        # Destination path and filename
        dest_dir = os.path.join('./input', folder_name, true_label)
        os.makedirs(dest_dir, exist_ok=True)
        new_filename = f"{format_confidence(confidence)}{ext}"
        shutil.copy(image_path, os.path.join(dest_dir, new_filename))

# Apply to high and low confidence images
copy_and_rename_images(high_conf_images, 'high_conf')
copy_and_rename_images(low_conf_images, 'low_conf')

# %%
# Display the results
pd.set_option('display.max_colwidth', None)

data_images = analysis(data)
data_images_retrained = analysis(data_retrained)

# %%
data_images
# Out:
#          true label  \
# 0  English springer
# 1       French horn
# 2   cassette player
# 3         chain saw
# 4            church
# 5     garbage truck
# 6          gas pump
# 7         golf ball
# 8         parachute
# 9             tench
#
#                                                                    image_min  \
# 0    /home/yi/Downloads/imagenette2/val/English springer/n02102040_1172.JPEG
# 1        /home/yi/Downloads/imagenette2/val/French horn/n03394916_46941.JPEG
# 2     /home/yi/Downloads/imagenette2/val/cassette player/n02979186_3672.JPEG
# 3            /home/yi/Downloads/imagenette2/val/chain saw/n03000684_590.JPEG
# 4              /home/yi/Downloads/imagenette2/val/church/n03028079_8572.JPEG
# 5        /home/yi/Downloads/imagenette2/val/garbage truck/n03417042_130.JPEG
# 6           /home/yi/Downloads/imagenette2/val/gas pump/n03425413_26601.JPEG
# 7  /home/yi/Downloads/imagenette2/val/golf ball/ILSVRC2012_val_00011581.JPEG
# 8  /home/yi/Downloads/imagenette2/val/parachute/ILSVRC2012_val_00002990.JPEG
# 9              /home/yi/Downloads/imagenette2/val/tench/n01440764_25090.JPEG
#
#    true confidence score_min  \
# 0                   0.136351
# 1                   0.066215
# 2                   0.143643
# 3                   0.102411
# 4                   0.202896
# 5                   0.158681
# 6                   0.067953
# 7                   0.134957
# 8                   0.112971
# 9                   0.268075
#
#                                                                    image_max  \
# 0    /home/yi/Downloads/imagenette2/val/English springer/n02102040_3221.JPEG
# 1        /home/yi/Downloads/imagenette2/val/French horn/n03394916_40741.JPEG
# 2    /home/yi/Downloads/imagenette2/val/cassette player/n02979186_11861.JPEG
# 3          /home/yi/Downloads/imagenette2/val/chain saw/n03000684_26780.JPEG
# 4              /home/yi/Downloads/imagenette2/val/church/n03028079_5402.JPEG
# 5      /home/yi/Downloads/imagenette2/val/garbage truck/n03417042_19481.JPEG
# 6   /home/yi/Downloads/imagenette2/val/gas pump/ILSVRC2012_val_00009821.JPEG
# 7  /home/yi/Downloads/imagenette2/val/golf ball/ILSVRC2012_val_00011431.JPEG
# 8          /home/yi/Downloads/imagenette2/val/parachute/n03888257_14472.JPEG
# 9              /home/yi/Downloads/imagenette2/val/tench/n01440764_10531.JPEG
#
#    true confidence score_max
# 0                   0.999499
# 1                   0.999999
# 2                   0.991158
# 3                   1.000000
# 4                   0.999355
# 5                   0.999999
# 6                   1.000000
# 7                   1.000000
# 8                   1.000000
# 9                   1.000000

# %%
data_images_retrained
# Out:
#          true label  \
# 0  English springer
# 1       French horn
# 2   cassette player
# 3         chain saw
# 4            church
# 5     garbage truck
# 6          gas pump
# 7         golf ball
# 8         parachute
# 9             tench
#
#                                                                  image_min  \
# 0  /home/yi/Downloads/imagenette2/val/English springer/n02102040_1910.JPEG
# 1      /home/yi/Downloads/imagenette2/val/French horn/n03394916_42912.JPEG
# 2   /home/yi/Downloads/imagenette2/val/cassette player/n02979186_7712.JPEG
# 3        /home/yi/Downloads/imagenette2/val/chain saw/n03000684_10960.JPEG
# 4           /home/yi/Downloads/imagenette2/val/church/n03028079_14992.JPEG
# 5     /home/yi/Downloads/imagenette2/val/garbage truck/n03417042_3331.JPEG
# 6          /home/yi/Downloads/imagenette2/val/gas pump/n03425413_8992.JPEG
# 7        /home/yi/Downloads/imagenette2/val/golf ball/n03445777_10141.JPEG
# 8         /home/yi/Downloads/imagenette2/val/parachute/n03888257_9671.JPEG
# 9            /home/yi/Downloads/imagenette2/val/tench/n01440764_14190.JPEG
#
#    true confidence score_min  \
# 0                   0.843360
# 1                   0.378967
# 2                   0.548982
# 3                   0.283426
# 4                   0.365760
# 5                   0.436759
# 6                   0.286137
# 7                   0.275994
# 8                   0.256993
# 9                   0.334159
#
#                                                                           image_max  \
# 0  /home/yi/Downloads/imagenette2/val/English springer/ILSVRC2012_val_00004650.JPEG
# 1       /home/yi/Downloads/imagenette2/val/French horn/ILSVRC2012_val_00004301.JPEG
# 2   /home/yi/Downloads/imagenette2/val/cassette player/ILSVRC2012_val_00008651.JPEG
# 3         /home/yi/Downloads/imagenette2/val/chain saw/ILSVRC2012_val_00007460.JPEG
# 4            /home/yi/Downloads/imagenette2/val/church/ILSVRC2012_val_00003682.JPEG
# 5     /home/yi/Downloads/imagenette2/val/garbage truck/ILSVRC2012_val_00002210.JPEG
# 6          /home/yi/Downloads/imagenette2/val/gas pump/ILSVRC2012_val_00004452.JPEG
# 7         /home/yi/Downloads/imagenette2/val/golf ball/ILSVRC2012_val_00009902.JPEG
# 8         /home/yi/Downloads/imagenette2/val/parachute/ILSVRC2012_val_00006561.JPEG
# 9             /home/yi/Downloads/imagenette2/val/tench/ILSVRC2012_val_00009191.JPEG
#
#    true confidence score_max
# 0                        1.0
# 1                        1.0
# 2                        1.0
# 3                        1.0
# 4                        1.0
# 5                        1.0
# 6                        1.0
# 7                        1.0
# 8                        1.0
# 9                        1.0

# %%
# Copy corresponding images to input folder for analysis
import os
import shutil

# Iterate through the dataframe rows
for _, row in data_images_retrained.iterrows():
    true_label = row['true label']
    image_min = row['image_min']
    image_max = row['image_max']
    
    # Create the destination directory if it doesn't exist
    dest_dir = os.path.join("./input", true_label)
    os.makedirs(dest_dir, exist_ok=True)
    
    # Copy the images
    shutil.copy(image_min, os.path.join(dest_dir, os.path.basename(image_min)))
    shutil.copy(image_max, os.path.join(dest_dir, os.path.basename(image_max)))
